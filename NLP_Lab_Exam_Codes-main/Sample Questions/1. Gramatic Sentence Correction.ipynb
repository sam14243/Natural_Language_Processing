# %% [markdown]
# # Dataset
# https://bekushal.medium.com/cleaned-lang8-dataset-for-grammar-error-detection-79aaa31150aa
#
# https://github.com/christianversloot/machine-learning-articles/blob/main/easy-grammar-error-detection-correction-with-machine-learning.md
# https://github.com/pushapgandhi/Grammer_error_correction/blob/main/Final.ipynb

# %% [markdown]
# # Task
# Given a statement, check whether it is grammatically right or not. If not, correct the sentence
#
# ## Pipeline
# 1. Data Collection
# 2. Preprocessing
#     + Tokenize
#     + Clean (Lowercase and Punctuations)
# 3. Model Building
#     + LSTM
#     + BART or T5
# 4. Inference
#     + Error Detection - Model should tell you the likelihood that the sentence is gramatically correct
# 5. Metrics
#
#
# ## Links
# - [Github Codes](https://github.com/pushapgandhi/Grammer_error_correction/blob/main/EDA.ipynb)

# %%
import pandas as pd
import numpy as np
import os
# %pip install jsonlines
import jsonlines
import re
# %pip install matplotlib
# %pip install seaborn
# %pip install wordcloud
import matplotlib.pyplot as plt
import seaborn as sns
import warnings 
warnings.filterwarnings('ignore')
from tqdm import tqdm
from nltk.corpus import stopwords
from wordcloud import WordCloud
import nltk
from nltk.tokenize import word_tokenize
from collections import Counter
# Out:
# Requirement already satisfied: jsonlines in ./.venv/lib/python3.12/site-packages (4.0.0)
# Requirement already satisfied: attrs>=19.2.0 in ./.venv/lib/python3.12/site-packages (from jsonlines) (23.2.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: matplotlib in ./.venv/lib/python3.12/site-packages (3.8.4)
# Requirement already satisfied: contourpy>=1.0.1 in ./.venv/lib/python3.12/site-packages (from matplotlib) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in ./.venv/lib/python3.12/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in ./.venv/lib/python3.12/site-packages (from matplotlib) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in ./.venv/lib/python3.12/site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy>=1.21 in ./.venv/lib/python3.12/site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in ./.venv/lib/python3.12/site-packages (from matplotlib) (24.0)
# Requirement already satisfied: pillow>=8 in ./.venv/lib/python3.12/site-packages (from matplotlib) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in ./.venv/lib/python3.12/site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in ./.venv/lib/python3.12/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in ./.venv/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: seaborn in ./.venv/lib/python3.12/site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in ./.venv/lib/python3.12/site-packages (from seaborn) (1.26.4)
# Requirement already satisfied: pandas>=1.2 in ./.venv/lib/python3.12/site-packages (from seaborn) (2.2.1)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in ./.venv/lib/python3.12/site-packages (from seaborn) (3.8.4)
# Requirement already satisfied: contourpy>=1.0.1 in ./.venv/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in ./.venv/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in ./.venv/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in ./.venv/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in ./.venv/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.0)
# Requirement already satisfied: pillow>=8 in ./.venv/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in ./.venv/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in ./.venv/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in ./.venv/lib/python3.12/site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in ./.venv/lib/python3.12/site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: six>=1.5 in ./.venv/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: wordcloud in ./.venv/lib/python3.12/site-packages (1.9.3)
# Requirement already satisfied: numpy>=1.6.1 in ./.venv/lib/python3.12/site-packages (from wordcloud) (1.26.4)
# Requirement already satisfied: pillow in ./.venv/lib/python3.12/site-packages (from wordcloud) (10.3.0)
# Requirement already satisfied: matplotlib in ./.venv/lib/python3.12/site-packages (from wordcloud) (3.8.4)
# Requirement already satisfied: contourpy>=1.0.1 in ./.venv/lib/python3.12/site-packages (from matplotlib->wordcloud) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in ./.venv/lib/python3.12/site-packages (from matplotlib->wordcloud) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in ./.venv/lib/python3.12/site-packages (from matplotlib->wordcloud) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in ./.venv/lib/python3.12/site-packages (from matplotlib->wordcloud) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in ./.venv/lib/python3.12/site-packages (from matplotlib->wordcloud) (24.0)
# Requirement already satisfied: pyparsing>=2.3.1 in ./.venv/lib/python3.12/site-packages (from matplotlib->wordcloud) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in ./.venv/lib/python3.12/site-packages (from matplotlib->wordcloud) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in ./.venv/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
f2 = open("/Users/daver/Desktop/College Work/NLP_Lab_Exam_Codes/Applications/resources/Grammar/en2cn-2k.en2nen2cn","r",encoding="UTF-8") # READING THE FILE

lines2 = f2.readlines()
inp2 = []
tgt2 = []

for i in range(2000): 
    inp2.append(lines2[i*3])
    tgt2.append(lines2[i*3+1])

# %%
inp2
# Out:
# ['U wan me to "chop" seat 4 u nt?\n',
#  'Yup. U reaching. We order some durian pastry already. U come quick.\n',
#  'They become more ex oredi... Mine is like 25... So horrible n they did less things than last time...\n',
#  "I'm thai. what do u do?\n",
#  'Hi! How did your week go? Haven heard from you for some time... Hows everything?\n',
#  'Haha... Okay... You going to mail her? Or you want me to reply...\n',
#  'Look for it on glass table in front of tv\n',
#  'Nah im goin 2 the wrks with j wot bout u?\n',
#  'Lea so wanna exchange hp number?\n',
#  'Ok see u next time then. Will be back in jul.\n',
#  "I'll meet u b4 lec then...\n",
#  'Hi! I am Ellen 18 chinese from KL.U?\n',
#  'Gelek got my msg? Help my chop seat k...Hehe\n',
#  'Plenty of old men...N guys ard 20 plus...Sick lei. Everyday msg...I go hm write profiles 4 u 2 c. Den where u workg now? There? As e recept? Y u littat?\n',
#  'Ya...Too heart broken..Scattered everywhere rem?Dats y woke up late...Hehehe no la...Heart broken but no course.Only 2 days.Watcha doin now?\n',
#  'Huh... Sure not. Juz go n watch lo... Heh. We meet oredi n c how k. So 5plus at orchard?\n',
#  'Haha. Okay.... How late? I go buy tickets first?\n',
#  'Hi! Can we chat?\n',
#  'Yar lor... But if go later hor we muz go by ourselves... Then how... Ü still sleeping ar me eating now oredi ü still sleeping...\n',
#  "Not fixed... As long there's still space in that class i think\n",
#  'Hi ranger how r ü\n',
#  'Yup... We are all here... Waiting for ü ...\n',
#  "We r not watchin movie oredi... I'm meeting them for dinner...\n",
#  'wondering if you could wake up for the 1030 class lor\n',
#  'Haha... Okay... Sure thing must carry around sch ah....\n',
#  'Monday evening or tues afternoon?\n',
#  'Where r u\n',
#  'Hey hows your driving test?\n',
#  'Ger v wan to go cheong today? zouk .\n',
#  '019870491 My mobile if u cant call me. i have msn. romny1980@hotmail.c\n',
#  'Cannot find la... Hair clip no nd to buy here wat... Wat hair clip she wans...\n',
#  'When I got back to singapore then punish you\n',
#  'Okay... I saw you...\n',
#  "Ok...I try...Coz i'm still on é bus...Is xin anywhere nearer?\n",
#  'HEY THERE BABE, HOW U DOIN? WOT U UP 2 2NITE LOVE ANNIE.\n',
#  'I am working at NTUC INCOMe, the sell insurance one.. A buildingnear chijmes..I do admin stuff, v simple one.. Wat are u working as?\n',
#  'Hee..U so bad leh,so long nv msg n reply me..U find me irritating huh?\n',
#  'Hi, happy new year! How have you been recently?\n',
#  "I'll pass u e notes nxt mon cuz got cca wk tmr.. Dunno if possible to meet...\n",
#  "I'm pubbin now, gee, cant go online...After my drivin ah, hmmm, den where ur meetin....\n",
#  "Both. no nd. com eng stuff. That's what my bro replied. Haha i think your fren will be disappointed\n",
#  'Okay thanks sorry today i was taking a nap must have sounded super sian\n',
#  'THING R GOOD THANX GOT EXAMS IN MARCH IVE DONE NO REVISION? IS FRAN STILL WITH BOYF? IVE GOTTA INTERVIW 4 EXETER BIT WORRIED!\n',
#  "2 wks... Den rest 4 abt a wk or so, den i'll b goin bangkok nxt wk... Quite hectic lor... So u juz slack ard now...\n",
#  'hey wan to go out next week???\n',
#  'so u know wheres the photo shop in clementi? Iszit instant? U wan take or not?\n',
#  "Yup this is our first mth.. Not only there will be more mths to come n even yrs to come. I'll cherish our relationship i promise.\n",
#  'Joe..why r u so quiet?\n',
#  "Hm... Wawa suggested we go watch movie then discuss photos over dinner then we go watch jy's play. At ps. Okay?\n",
#  'HI THERE ANY 1? IM NESH AGE 23F. KL. ANY 1 CARE 4 CHAT?\n',
#  "By the way i'm malay hope you guys don't mind\n",
#  'Hey are you doing the eng mod this sem?\n',
#  "Yup... I will call you in a while? I'm booking my lessons online\n",
#  'Hey i managed to configure my laptop... So no need to look for the piece of paper... Thanks!\n',
#  'Haha... no of coz not, stupid to go alone\n',
#  'roy hi care 4 a chat?Intro\n',
#  'maintenance technician hw abt u?\n',
#  'Haha eh fri i got driving! If i sat no lect i will be going home on thurs and only coming on mon liao. Okay lah see you tmr. Hey you saw my email? How to collec\n',
#  'Tmr i end at 2 ! I can meet you.\n',
#  'Of cos got la... I bought boxer 4 dada, candles n macadamia 4 mama... Got chocolates, almonds...Accessories....\n',
#  'Hey are we going out tmr\n',
#  "Good Morning! Hope it's gonna be a smooth day for u! Take good care!\n",
#  'Violyn can you intro.?\n',
#  "Okie... But i'll b late lor... My doggie juz gave me some work to do...\n",
#  'okay... Cya after lesson then\n',
#  'HI DARLIN IVE JUST GOT BACK AND I HAD A REALLY NICE NIGHT AND THANKS SO MUCH FOR THE LIFT SEE U TOMORROW\n',
#  'Oh hey we meet up this sun instead to celebrate yin bday. What ü guys wanna do?\n',
#  'Hey you got bring pad along with you a not?\n',
#  "Okie... Den u'll reach ard wat time....\n",
#  'dear.. im gonna slp le.. u slp early too k . Good nite :) *hugz*hugz*\n',
#  'i tink i get her flowers,hee... or smting... i wun stay long lar.\n',
#  'Y so late still havent slp yet?\n',
#  'Oh ok i didnt know what you meant. Yep i am baby jontin\n',
#  'Sch uniform la... At hwa chong bridge... Eh later ask daddy dun pick me, i wan to stay in sch do work...\n',
#  'I will create something interesting for us to tok abt ... Don worry ...\n',
#  'Anywhere lor... Me at bugis now...\n',
#  'If i pass the evaluation then book lor. Tmr we meet at 11 ?\n',
#  'At home lar... Where r ü... Mum ask ü to buy colgate...\n',
#  'U reach school den msg me lah..\n',
#  'ok gd..i m consolidating more responses..get back to u once all responds\n',
#  'Wha still wan 2 buy cake. 1 whole cake or jus slice? 4 of us can finish mah? Orchard got quite a lot of shop.\n',
#  'Hi nemo!\n',
#  'Tell u tonight. Let me c how my hair lk like first.\n',
#  'Ya la... Of cos collectin la... Wat u wan?\n',
#  'Eh... This one i dunno leh... Haha... Maybe just bring ñ see how?\n',
#  'Wah... Its fated then... Ü hiya, ü get attached lah... Or juz find someone to be ur attach n really act well lor. Ü must also really act v well then!\n',
#  'Wat buses go to ur sch frm amk huh...\n',
#  'GRAN ONLY FOUND OUT A FEW DAYS AGO.CU SOON HONI\n',
#  'hmm,both of my friends coming r guys..but i dun dance.they do.actually i am there4 e drinks only..so how?\n',
#  'So u stayin in e hostel?\n',
#  'I am going to see movie now\n',
#  'Tmr i can only mt u durin my lunch break...Wed la...\n',
#  'Hey... we can buy the 42 one lar... Since we are sharing? But corinna can carry a not?\n',
#  'Yeah wana save n stinge... We shall eat smting good.Got earlier i knock off at 5pm leh,sure reach b4 530pm\n',
#  'Fetch us at 7pm\n',
#  'Yunny dear u wan to go for ur nus law bash tonight after ur movie? Hee\n',
#  'I go bathe first. U can ard 2.\n',
#  'If lydat i cant do anyting.unless u already decide,i try to help u find seniors to help u.but u haven confirm anyting.\n',
#  'Mine was not. It said that the gal who sent it to me was the one i love. Thats definitely not... Haha.           Hmmm.... Im someone ü can confide in ? Hmmm...\n',
#  'got meh.. mine is local one...\n',
#  'Y bitch?Dun dare reply?U,yun ur mum,all r bitch,ur dad of cos a bastard lah.U beta ask yun kol me,if nt..Haha.U all wan play,jz c.Bloody bitches\n',
#  'u got cash card w u now.. xin wan to photostat something..\n',
#  'Stop liao.. E ikea ppl just came.\n',
#  'Haha. Oops. I didnt see your msg. Ü want to go at 9?\n',
#  'U say b4 dat u haf ans 2 ST1232 exam papers rite? Can u bring the ans tmr?\n',
#  'Prob at some coffee place... Coffee club wisma or taka...\n',
#  'Nope... But mayb his heart got say... Hee...\n',
#  'Joey: YOGI CARE 2 INTRO.\n',
#  'Hey dearies.. On da way to e airport now.. Can msg me at 93466348 if u wanna contact me k.. Cya all when i get back! Luv ya!\n',
#  "I wuz jus teasin u abt ur drivin.Even though i noe u'll pass.U sleepin?Ok... :(i guess ur tired huh?\n",
#  'Huh... oh! Thats the wooden one right? the aluminium one cheaper\n',
#  "Oh... Lk tt ah... I'll b goin dwn ard 11... Sittin 4 evaluation first... Den later got drivin...\n",
#  'Yup. But now havng lunch near my house here.\n',
#  "Sorry for late reply.Wuz damning,ü,some recruit juz now.He frm acj lei,my english cant't be too flowery 4 him to understan.Blood boil...Go bathe 1st.\n",
#  'Joey: Hai! ryan care intro.\n',
#  "I'm in my room... Later when you are done you call me. I meet you at central library?\n",
#  'PICK UR FONE UP NOW U DUMB?\n',
#  'Rain,u busy nw? Y so quiet? Speak up.\n',
#  'Where got domain la... Cannot even connect...\n',
#  'No la... Dun have any cute ones, sad... Gee... K nitez....\n',
#  'Tats when u finish driving? hmmm.. ok den..\n',
#  'Oh no... That means you arent coming for stats? Then you cant help me print... Coz i need it right after that... Okay. All the best for your test! Dont worry\n',
#  "I'm goin to airport to send my dad off...\n",
#  "I'm 25 staying at tph\n",
#  'Just came to nydc n she just ordered a baked rice n i ordered a drink. U done liao.\n',
#  'Hey you still in library?\n',
#  'The number is 63383526. Ask her call after 12 noon tml k! U call nydc yrself k. Faster...\n',
#  'Haha... Ok... Hope u can remembe to help me ask... Heehee\n',
#  'How i noe... Last time tis one is on offer wat...\n',
#  'Sat lor. Can?\n',
#  'Why?ofcourse f. Dont believe. U jordon?\n',
#  "Exactly...How'd u know...But it wuz a pillow.So i neva earn.Contrary to most views.:p u'd look really cute.Hehehe.\n",
#  'Huh she c oredi... Then i oso dunno how lor... If we go c nemo den she cant cum along rite... So mayb eat dinner lor... I dunno...\n',
#  'I wan to work full time, not part time...Crepes ah, dunno leh, prefer nydc...\n',
#  'Wu jian dao got sneaks ah? I anything\n',
#  'I oredi cleared once, he still wan to mess up wat to do...\n',
#  "Me n yun go change smth 4 mum... I saw elvin outside our hse... But dunno whether he's still there a not...\n",
#  "BOO BABE! U ENJOYIN YOUR JOB? U SEEMED 2 B GETTIN ON WELL HUNNY! HOPE URE OK? TAKE CARE & I'LL SPEAK 2U SOON LOTS OF LOVE ME.\n",
#  "Hey do ü want to go for eusoff's hall dance production bash on 18 oct, embassy?$15 includes 1 free drink, 1 for 1 frm 12 to 1am. Tequila shots at $5 each.\n",
#  'Anything my darling buys i will eat...  Heehee.\n',
#  'WE REGRET TO INFORM U THAT THE NHS HAS MADE A MISTAKE.U WERE NEVER ACTUALLY BORN.PLEASE REPORT 2 YOR LOCAL HOSPITAL 2B TERMINATED.WE R SORRY 4 THE INCONVENIENCE\n',
#  'Yup... Wah. How come you choose comp sci? After discussion with parents and sis? What mod ü need to take? Ü need to take stats? And ü doing gem this sem ?\n',
#  'WHO ARE YOU SEEING?\n',
#  'Anytime. Or u all going to leave den i pick u all? Town like nothing to eat at this time hor.\n',
#  'U wait for me outside e taxi stand k.\n',
#  "Ah... U got tuition in e afternoon... Okie lor... Haha, my sis ask if can borrow ur card, she wans to go kb oso... Haha, so mean...So i'll meet u 4 drivin lor..\n",
#  'U juz sit behind 1st then move during e break.Impt stuff u beta nt miss..Ü\n',
#  "Die i thk now my supervisor thk i'm v stupid... Cos i applied 4 e wrong acct... Arghh...\n",
#  'Hmmm okay... Thanks... Put a pen!\n',
#  "Hey i'm in town now r we meeting today?\n",
#  "Hello... How's ur day... Oh ya, wana tell u tt i'll b workin until nxt wed only...Haha, takin a break...\n",
#  'Okay thanks... Study hard... Cya tmr!\n',
#  "Eh what's the name of the japanese restaurant at esplanade?\n",
#  'U at marina?\n',
#  'Like all quite far. èn after ür suntec one.ü stil lkg for jobs?\n',
#  'D n J. sean. wet field select light body wt between 450-470. n light wt have strength from behind because leading horse reduce the speed.\n',
#  "I'm thinking wat r u doing now. Me now at home watching tv. Think now u shld be in shanghai.. Quickly enjoy ur holiday, u r coming back soon..\n",
#  "I'm goin to aust... Comin back on 4th of june...\n",
#  "I'm in the office of .\n",
#  'Hey no I ad a crap nite was borin without ya 2 boggy with me u boring biatch! Thanx but u wait til nxt time il ave ya\n',
#  "Hey i'm at the lt 24 toilet.... Med blk level 2 okay\n",
#  'Hm, any show would be fine with me... Wat ü have on after four?\n',
#  'Joey: Neo where u fr?\n',
#  'I dun have any lobang.... Thgt u workin in bank...\n',
#  'No... I jog like 2 rounds den feel like dying liao... But too long didnt exercise my legs feel v funny,so decide to go today... Hehe...\n',
#  'Wake up already. Now still lying on my bed.\n',
#  'Stop it! Cant take it anymore. Then u go n sleep now lar.\n',
#  "my linear algebre tutorial's on friday 1-2. yours?\n",
#  'Ü all go then i go lor... Free one wat...\n',
#  'Yup i will be... But the booth wont be... Haha i go there see see lah. But those are the comms leh you interested? Like publicity that kind\n',
#  'millian no. buy 5 big ok loh\n',
#  'Den where is e nearest mrt station tt u can meet me?\n',
#  "Shucks... I lost e envelope... Can i juz replace it w my own? Anyway how's ur trip so far?\n",
#  'haha who are ü arh? New no on my fone so sorry\n',
#  'Aiyo... Go out again ah...Cant la, v tired...\n',
#  'Joey: Hai! anybody want 2 chat?\n',
#  '1st wk sports unlimited extreme camp-eca- 2nd,hall camp.\n',
#  'Okie gals our burfdae cannot make it tmr.. So changed to tue.. 10am at toa payoh bus int.? She wans to go ecp.. Everybody can make it? Hee\n',
#  "Help! It's raining... I'm going to get drenched...at science now....\n",
#  'Today? Cant la, i din even brin e notes out...\n',
#  'Yah... But its so sad that national day is on sat instead of a weekday...\n',
#  'Yup wat time r they going?\n',
#  'I dunno... Leh... I dunno whether i should go a not leh. Still deciding... Do they cut it very short.\n',
#  'This Thursday evening, Ah Soon invite u for 7th month dinner. Meet @ #02-34 about 7.30, ok?\n',
#  'Just gettin a bit arty with my collages at the mo, well tryin 2 ne way! Got a roast in a min lovely i shall enjoy that!\n',
#  "Can't find me?i in hall lo.call my hp if got urgent stuff.i in hall wil on sound for calls.\n",
#  "How abt ya driving? cos i'm going amk to study..\n",
#  'My fren say still got la...\n',
#  'R ü going to b done anytime soon?\n',
#  'Ben says to wait at da mrt bus stop... Xinyi will b there too... But ben staying over nite lei... Ü wan stay a not...\n',
#  "Wat? I'm in e movies....\n",
#  'Hmm i really dunno wat ü want... Make it more explicit can? ;p hiya... its my pleasure to see ü off anyways ü\n',
#  'U still outside w friends?\n',
#  'How do use excel...? Can instruct me how to use it?\n',
#  'Den buy how many box... I juz pass by tis shop, dunno wat brand la... Here got mng too... Shld come here 4 hols, can stay in tis apartmnt...Haha..\n',
#  'Hmmm b7l_jammer that is L ..Hotmail...Hmmm you add me msn ba...\n',
#  'Whats your msn?\n',
#  'eh.. s can i get from ya e notes today?\n',
#  'Wah today rainin cats n dogs u wan me go running? 2 days ago run 10 k liao... Heheh but fire burn out. Wat time u flyin?\n',
#  'Ya i noe haha got 2 interviews bt watever la juz try lo heez i also got chose nus sci\n',
#  'Lea yes i from singapore.\n',
#  "Was there ard 6... Yupz, i suppose she's still there, i left oredi...\n",
#  'ok!\n',
#  'Orhz... If u change yr mind call me... Me going... Heheh...\n',
#  'Where are you and mother and yun\n',
#  "Go to namly ave, bukit timah there, near hwa chong tt area... Thk it's called namly clinic or somethin...\n",
#  "li en's new no.the person asked me if ü changed ur no.i suspect it's elvin coz li en said she didn't change no..\n",
#  'Hey ü study already ?\n',
#  'If nice then buy lor... But mambo watch so ex meh... Half price still need 58... Tmr u still got time 2 buy meh...\n',
#  'Eh.. no prob.. i can always pass to u.. eh.. i will pass by ur hse outside bus stop everyday u know.. or u wanna meet some place else?\n',
#  'On e way la... U skip lect la... Den go shop...\n',
#  'U  R THE MOST BEAUTIFUL GIRL IVE EVER SEEN. U R MY BABY COME AND C ME IN THE COMMON ROOM\n',
#  'can intro pls?\n',
#  'Ü supposed to b on da bus y ü go n eat yoghurt...\n',
#  'We goin to claim vat...\n',
#  'Ok then when i reach i go collect ticket first. Now i nothing to do watch tv.\n',
#  'Hey... U go read e classified today... Got quite a no nd sales gal in town one...\n',
#  'hey i think i will go cut lah. Ü think can get slot at 2 ?\n',
#  'No lo..Suddenly get sick one.Hehe..Ur fren also sick ar..\n',
#  "Hmmm... I'm okie w anythin lor... Which do u prefer...\n",
#  "I oso din noe one.it's like e whole world noe le.èn i noe.it's hall de ren.erm he's nt gd lkg 1.but ñjoy his stories ñ swt.but we dun reali noe each oèr well.\n",
#  'No lah...Different... Mine is com engine...Nt together wif computing...I wan to noe pple going in wif me leh...Haha\n',
#  'Hi baby ive just got back from work and i was wanting to see u allday! I hope i didnt piss u off on the phone today. If u are up give me a call\n',
#  'I dun haf lessons tmr..How abt on tues?\n',
#  'so sian, anywhere oso cannot go... actualy i dun really care bout it.. u dun save money like tat la.. if not let me pay next time.Ü\n',
#  "I'm goin orchard now.but gota go home for dinner.but can pei ü eat.hee-\n",
#  'Zping at her house so she not free. Then if 7plus at amk central u ok or not?\n',
#  'Ü got enuff money to take taxi home a not?\n',
#  'Congrats can celebrate today... No wonder dat day u dun wan to say... So hw many pts u got?\n',
#  "I clear for him again oredi... That's y i say he's a naughty boy...\n",
#  "i noe there's no solution ...\n",
#  'My dear gers...R u all bringing body foam? Coz i seem to haf alot of bottles\n',
#  'Thanx u darlin!im cool thanx. A few bday drinks 2 nite. 2morrow off! Take care c u soon.\n',
#  'oh..ok..should have told me earlier.then will go find ü..well,enjoy ur lunch!catch up with ü soon..\n',
#  'Hey dearies...Juz in case u are interested...Mango 50% off =)\n',
#  'Yesterday u made $225 to day $375 tot $600.\n',
#  'hey you going for eng tmr?\n',
#  "Eating noodles..Okok..I'll remember if i gotta e honour to...Keekee..\n",
#  "I went amore 4 lesson ma... Tt's y nd to pay lor...\n",
#  'I thk tonite cannot... Another day...\n',
#  'Anything lor... Today can oso...\n',
#  'Today went strawberry farm, lavendar farm and winery... I bought 2 bottles of wine... Gee...\n',
#  'U forgot to gif millian his dog bone... Later his tooth ache...\n',
#  'Okay... Ü call us when ü reach... My drivin is at 240 tmr... Ü have 2 lessons? Or only one?\n',
#  'HEY DAS COOL... I KNOW ALL 2 WELL DA PERIL OF STUDENT FINANCIAL CRISIS! SPK 2 U L8R.\n',
#  'Hee... Me free so any day go also can. U ask shuhui. Or can go cut hair or take photo also.\n',
#  'Sorry forget 2 tell u. Think dont wan, u all go ahead.\n',
#  'Dont get angry with me,i jus 1 2 make frd with you.\n',
#  'We saw fiona xie at taka... Haha...\n',
#  'then... i end of year then see u liao la.. haha.. so btw.. wat u doing now?\n',
#  'Yeh.but make it on sat k.can?\n',
#  'Hi,cy.location,age,gender pls\n',
#  'Da sardines ü used like put very long oredi izzit...\n',
#  "Huh? Wat's dat? New movie? I still haven settle my show with u ah!! Haha\n",
#  'Eh... U buy ticks huh... Help me bring my ring out oso, in my room...\n',
#  'Hmmm... I have to ask my dad abt e insurance lor... Ur signin up?\n',
#  'Oh is it, got a few friends there. I repair tanks, heh, but my army life quite slack lah. I play alot of sports. So far i took part in soccer, basketball,tennis\n',
#  'Okay... We are on the bus already...\n',
#  'how abt e price i asked? Is it acceptable? If yes i would like to have a look at e book this evening. If on problem then  i will buy it st away\n',
#  'I suppose so, is it win xp?\n',
#  'Well, juz hoped you had a lovely day. Stay happy....  :)\n',
#  'hi jesslyn here, me using my uncle hp to msg. me just change my hp no. to 91073084. rem ok... enjoy e nitez!\n',
#  'I dance la, bt will b too tired to dance liao... But i oso dunno ur frens ma, hard to chap ard...\n',
#  "You saw? It's up already ah? Haha\n",
#  'Hey sorry ah... Ü free this sun?\n',
#  'Reach home liao.. Gd nite n sweet dreams my dear..\n',
#  'Haha.. nv cut den dun return u...haha.. ok lar.. i den cya there slightly before 1245 k? nites!\n',
#  'Ur dog very naughty lei... He cant shit all at once one lei... Muz shit 3 times very tiring one lei...\n',
#  'Same wa sch u study\n',
#  'Oh ok... Then i go bishan n meet ü oso rite...\n',
#  'MY NEW YEARS EVE WAS OK. I WENT TO A PARTY WITH MY BOYFRIEND. WHO IS THIS SI THEN HEY\n',
#  "Huh... Haven thgt abt sat lor... Mayb two sets... I'll bring some snacks perhaps...\n",
#  'HIYA COMIN 2 BRISTOL  1 ST WEEK IN APRIL. LES GOT OFF + RUDI ON NEW YRS EVE BUT I WAS SNORING.THEY WERE DRUNK! U BAK AT COLLEGE YET? MY WORK SENDS INK 2 BATH.\n',
#  'Angle y ü no reply mi i m iceman\n',
#  'Shall i buy tis mambo watch tt cost 80 bucks...\n',
#  'No need gd luck liao. I fail de hen can... Yup same place\n',
#  'Ok i reach there at ard 630.\n',
#  'keke, i will do my best,hehe just sold one\n',
#  'Hi,hw s evy1?care 2 chat,any1?\n',
#  'She stalk my father 1yr le... Police oso no use... He go ur hse? Y so bian tai de\n',
#  'Which part of msia r u frm?\n',
#  'Ü finish ur exercise oredi ar... Wat ü all having for dinner...\n',
#  "Me n xy meeting 4 dinner. I'm in town oredi. So Wat time u wan 2 meet?\n",
#  'Thanks... You went bangkok? Got buy anything for me... Hee hee... Today you no school?\n',
#  'Ah... I also want to watch! Sigh... But i watching last samurai on monday already...\n',
#  'Not gd day today... Very sleepy now... Slept 4 3 hrs only. So u off day ah...\n',
#  'Ill be at yours in about 3 mins but look out for me\n',
#  'Haha.. ok ok.. aiyo.. so he handsome or not? haha..\n',
#  'Not offer but need... Typo...\n',
#  'hi roy ! Intro pls ..... Pls sms at 016 5419814\n',
#  "Haha... K... I'm gona b late too...\n",
#  'Yeah, probably but not sure. Ilol let u know, but personally I wuldnt bother, then again if ur goin to then I mite as well!!\n',
#  'Hey really sorry bout ur pouch... Really din mean to forget to bring or anything... Sorry lah... A kiss to make it up?\n',
#  "Yupz, 7 n 8... I'm goin, promised cindy liao...\n",
#  'Hello.. U there? Wat happen to u?\n',
#  'Okay we go for dinner then?\n',
#  'Vivian intro plz\n',
#  'hi my darlin im on my way to London and we have just been smashed into by another driver! and have a big dent! im really missing u what have u been up to?\n',
#  'I found it at bugis... Ü are rite...\n',
#  'HELLOGORGEOUS, HOWS U? MY FONE WAS ON CHARGE LST NITW WEN U TEXD ME. HOPEU AD A NICE WKEND AS IM SURE U DID LOOKIN 4WARD 2 C-IN U 2MRW LUV JAZ\n',
#  'Wa... Really ah, very hard to get in leh... Thk muz go 4 interview oso... Anyway, wish u gd luck oso la...\n',
#  'what time? now gonna rain\n',
#  'Really... Catch e kitten leh... Den can play w millian...\n',
#  'U free tmr? Wana watch finding nemo...\n',
#  'CHEERS FOR CALLIN BABE.SOZ I CULDNT TALK BUT I WANNA TELL U DETAILS LATER WEN WECAN CHAT PROPERLY\n',
#  'hey i have a new number.. 91074867 yep. i chose biz ad. you ?\n',
#  'Welcome to hi!Card by SingTel Mobile. Divert calls to 1344 for Voicemail. To send SMS, change SMS service centre no to +6596400001. Call 1800-4822800 for info\n',
#  'U enjoy urself over there?\n',
#  'Hi BOEZ,DREDZ,MOSES can intro pls?\n',
#  'In tis lovely nite, I pray 2 the blue moon 2 protect U thru the nite, the wind 2 blow away ur stress N the twinkle stars 2 guide U the way, sweet dreams Gd Nite\n',
#  "I'm in engine do some studying lor. U leh?\n",
#  'Hmm... toysarus? places tt sell balloons. Hee- but no pin lei. Queensway?ür peninsula lei?\n',
#  "I'll be late 4 ? meetg...probab 10 mins.\n",
#  'Hey other then intro what are you doing? Ming lun got tell you?\n',
#  "Yun ah.chinatown's hawker centre close lei-for cleanin.\n",
#  "Hey... I'm hungry... Are u ?\n",
#  'Ü wana watch wad?\n',
#  'Going to reach already\n',
#  "Eh... Ü all going to ben's place on sat...\n",
#  'I saw li nanxing... At da an pang yong tau foo there...\n',
#  'No,me juz got home from unit run at bishanpark.How come sleep so little,go back to bed then. How r ü spending yr saturday?\n',
#  'Eh. Take from where? Amk? How to go from yck?\n',
#  'Good morning! :) i jus did my test.. dun hav enough time to do it.. haiz..\n',
#  'pls sms me d name of d wat lotion is that ?\n',
#  "Of course pay oredi... Or else how i come out... Mayb urs oso 25 cos i thk highlight is 25 then if ü colour ur whole head it's 35...\n",
#  "I'm goin 4 lect later... So pick me up at 6...\n",
#  'K.reen u change ur number isit?hw cme neber sms 2 mi...so sad..:(\n',
#  'Good Morning! Had your breakfast?\n',
#  'Haha... I brought ur wallet out, u la nvr take out... Bt nvm, cos i forgot to brin money out oso....\n',
#  'Thx 4 turning up. Hope u had a gd time. I had ü\n',
#  'I dunno la... Say i nvr shop, i juz pass by... Aiya, can go internet n get e details wat...\n',
#  'Joey: hai! care intro neo\n',
#  'Hmmm... They din really say much abt it... Okie, nvm...\n',
#  'joe,ur name rminds me of a long lost friend of mine name JOMIS.\n',
#  'Ok...So did u get the idea i wuz green?\n',
#  'I meet ü at ten at the lab we used to use when we r in cz 1102, k?\n',
#  'Hws ur wk my fren?\n',
#  'Hi intro please\n',
#  'Haha... All your exercise went down the drain... Oh, im on duty today. Nothing much to do so im cycling ard camp...\n',
#  'i think what i hav told so far is no big secret...\n',
#  'Haha... ü must look at the updated sheet also leh\n',
#  'Me jordan, what take u so long to sms my hp number\n',
#  'Oh, it was juz a chinese message. Wat hp you change to?\n',
#  'Hey i managed to book the 1245 lesson on friday too?\n',
#  "Hey jiayin... Can bring 10 bucks tmr, it's 4 wawa's bdae...\n",
#  'not enough credit.\n',
#  'No money to cut lor... Haha, no la, juz feel lk keepin it until end of tis year den cut short short ma, lk tt den shiok wat...\n',
#  'Opps..maybe every one else is late?or maybe mingfang is at your lab?\n',
#  'Hi Moboy! Pls call me 0166305681\n',
#  'Hey... My lesson tmr at 440 leh... Tt means i wont cya liao...\n',
#  'Me lyin on da bed oredi... Nite...\n',
#  'Hey yun... Can you help me print something out tonight and pass to me tmr?\n',
#  'I think it will be harder than your hk trip.\n',
#  'can you open your hand phone\n',
#  'Email to yur tutor.Muz put yur name ya..+send to e seow email too.\n',
#  "Hope so... call ya when i'm better :)\n",
#  'I sick lo..Not feeling well then today take mc la..Hehe...\n',
#  "Yup, i replied 'okie' to ya icq. u mean icq charge us? even i send to ur phone, oso wil charge wad..\n",
#  'Good NiteY.. SwEeT dreaMs..  miZ YoU, n Take Care! ... Josh  ;)\n',
#  'Ok then...Did U go check out e book?\n',
#  'Thkz... So how have u been doin? Havin exams now? Hope to meet up w u sometime... =5\n',
#  'Eatin at far east lor... Goin to drink coffee now...\n',
#  'Okay... YES. both of my parents will mind. Very very obvious. No need sun can see that kind\n',
#  "Hey xin... I'm in sch oredi... Later might not b able to meet u. Cos my sis leavin ard 12 plus...\n",
#  'Hee hee...  Poor thing. You can go out for shopping or something when yr tests are finally over. Im having a bad sunday. Down wif a cold...\n',
#  'Oh, ü muz be dead tired then. Haha.... Wah, so far also, at tuas.  Hope its not pouring there, its pouring at my place...\n',
#  'Have you finished work yet? :)\n',
#  "Hmm... Short ones like da blue one dat i've from 37 degrees... Thanx... Hee...\n",
#  "U call me tt time i'm bathin ma...Haha... Anyway later got nice show, got jay chou...\n",
#  "Wat's da temp down there... So ü all not going anywhere special today... How's da apartment?\n",
#  'May i know ur handphone number\n',
#  'I am here already\n',
#  'I see.... So where you went yesterday?\n',
#  'Yeah... not fun your head! Damn slack can, then the chicken wing damn nice somemore\n',
#  "Then millian's membership card number ü wan to buy how much?\n",
#  'So tmr meet u at 1015 outside somerset mrt k...\n',
#  'hey meeting corinna tmr,wed at 12 orchard mrt.going nooch 4 lunch.can pass the msg to huixin n yun 4 me?do reply me if all u 3 going k?thanx uncle!cya..-jo- =)\n',
#  'can see that u are vry sad.. pls dun be, there r many other first time in future :) cheer up k. Ü\n',
#  'Yah lor, last min one.. With my father friend.\n',
#  'I reach le find me at e lesser ppl public phones corner\n',
#  'Dunno lei... N she neva tell us rite... She only told ben... Ü ask her lar... Ben got book a room at sentosa lei...\n',
#  'How much i have?\n',
#  'Hey, are u still in school? Wanna go lunch with me n wei yi?\n',
#  'Morning...Sailing off later..Take care..\n',
#  "But i dun look good with short fringe!! Sob sob.. Oh well it's cut.. So after u cut we go dye hair together? Good luck for ur papers!\n",
#  "Ok ppl tis sat 7jun we'll meet at tiong bahru mrt ctrl stn at 130pm pls bring ard $15 4e chalet n bbq...those goin sentosa on ur own let mi noe...thx!\n",
#  'Hi Paul, h waz ur day? Lea fm25. U?\n',
#  'Hey u haf unix acc in soc..Can lend mi yur passwd? + unix acc? I juz wana try sumting can? Thks..\n',
#  'Okay. cya...\n',
#  'Then too bad for me lor .. anyway doesnt really matter also ..\n',
#  'Erm.. Cant tell first la... Later u will know one.. Can la...\n',
#  'Haha... Ur dun go jian fei without me ah... Wait 4 me... Oh ya, i juz email u e website to e photos... Got time den go c c...\n',
#  "What're you doing tonight?\n",
#  'They inside e restaurant liao.\n',
#  'Really how much...\n',
#  'R u yijue?\n',
#  'Leaving ard that time too.  Bringing laptop home?\n',
#  'Ya... Said goin w wawa liao wat.. Still muz take mrt ah... Haiz...\n',
#  'Nite has end for another day, morning has come in a special way. May you smile like the sunny rays and leaves your worries at the blue blue bay.\n',
#  'Okie u msg me ur ic no n add? Ur yiyun is together rite? Or sep?\n',
#  'Eh u go wear uniform den can get ticks to watch turn left turn right...\n',
#  'really.oh.nearer to my wkplace ñ stella choose one mah.\n',
#  'Haha u v funny. Aiyah suan le lah, when we do our project we also make some mistakes. Face skin thicker lor, never mind one lah.\n',
#  'hehe.. dun like tat say leh.. i vry responsible one leh. Ü go and enjoy e show. cal me later k :)\n',
#  'Oh ok...\n',
#  'Hey i hear postings out online... Go check !\n',
#  'Pick you at 9-30PM-Behind\n',
#  'violyn y no reply frm u can u msg me at 90853276?\n',
#  'Ü bought ur camera at which shop?\n',
#  'I din enlarge and c, so not sure got cute guys anot... Ya, got u inside wat, wow so sweet yo... Ya, e big heart one quite nice, but urs more creative wat...\n',
#  "Okay. I'm at city link already\n",
#  'Wat are you doing now? Asleep yet?\n',
#  'I c... remember to let me knw when u cm back\n',
#  'JESS wat r u workin s\n',
#  'Haha i remembered! She\'s my "lover" now liao-- cedes wat time were ü there? Is she still there?\n',
#  'Oh, wanna go there ma\n',
#  'i cant understand my linear algebra tutor. i think hes from china. cannot understand what hes saying.\n',
#  'Hi.. How was calculus? Feel that e lec is not so beneficial.. E tb seems enuf.. Dunno whether i wanna continue coming or not..\n',
#  'Mick, go to die\n',
#  "Hey...Harry potter out today... Ask daddy to buy 4 me! It's 33 bucks in popular...\n",
#  'Hah in wat way not nice?\n',
#  'Where r ü all going?\n',
#  'Moment\n',
#  'Hey j! r u feeling any better, hope So hunny. i am now feelin ill & i think i may have tonsolitus aswell! damn i am layin in bed real bored. lots of luv me\n',
#  'Can i confirm w ü e time tmr?\n',
#  'Oh. Again. Wow. U lik very guai tis fw wks.\n',
#  'And if ü wkg waitress or telemkt.i tink part timer better ñ get a few -if ü find hrs not enuf-one of my odac fren earned quite abit like tt.ñ owis go out.\n',
#  'yup..\n',
#  "He told u i'm considering liao mah. I duno, i not v interested in e show n i dont wan go out on both weekend. Sunday we meeting 4 lunch w e rest right.\n",
#  'Wat u eatin?\n',
#  'Im working ... R ü ireena\n',
#  'Hmmm.... After my drivin den free lor... Y?\n',
#  "R u colour blind it's blue not pink.\n",
#  'Oh...Ok.Gud!thank goodness u forgot.is everything ok?Or now e point system drop liao?\n',
#  'Yar then can say hi... Then later can go for dinner... He like doing project...\n',
#  'Hi, u male\n',
#  'Wat u doing?\n',
#  'At a store outside emporium\n',
#  'Really meh strange é no. I hav is 94 something 1 k la nvm hows life?\n',
#  'She say da 12 lessons ü can go for any class... Then da unlimited one for 3 mths is 330... I havent sign up yet...\n',
#  'Mrt station upstairs k.\n',
#  'Aiyo... Hamster die liao... I got no time to clear...\n',
#  "Call 93864500 ñ ask if they got any telemarketin vacancies.tis is the hdb hub one.it's job briefin is tonight leh.so better call asap.\n",
#  "Hi.......everybody! Me.....i'm fine... ñ wish to chat wif ü guys. Can sms to 96792371. K....\n",
#  'Haha. Oic. So u must hv put on lots of wt loh. Me ar? Nv loh. Little oni. Ke lian sia.\n',
#  'I jus managed to get hold of my charger.. phone died on me for e past one n a half day.. But i dun wan to cut until very short wan noe..?\n',
#  'Buy some more mangosteen back lei... Da mangosteen v sweet...\n',
#  "Hello, hello, hi lou sorry it took so long 2 reply- I left mobile at friends in Lancaster, just got it bak Neway im sorry I couldn't make ur  b'day 2 hun!\n",
#  'Haha... Sorrie abit blurr liao... Havin too much lesson... So hows life for u?\n',
#  'Ok can, i wil upload again. But u make changes to carfinal1.Clp is it?\n',
#  'Hi JOY can intro pls?\n',
#  'Joey: HELLO R U GUY OR GAL? ME GAL\n',
#  'Guess wat im e one whose gonna b late..gee...\n',
#  'Nvr c any... Dunno wat size u fit oso...\n',
#  'Well... Izzit true for u?\n',
#  'Hey i cant stay out late tmr night...\n',
#  'Nope maybe lecturer will list out the topics tmr\n',
#  'Yup... You got it?\n',
#  'U say u wan eat coffee club cheese cake then is Orchard lor, else nearer bishan or amk.\n',
#  'game for a drink later\n',
#  'U lookin 4 june huh... Came back muz pia drivin oredi... Cos miss 2 wks, later rusty...\n',
#  'im sleepin, jus woke up.. vry sian oso. wad r u doin now?\n',
#  'No more stairs liao? Its bad for your knees so stoppin is quite good. Wat homework r u rushing? 1pm flight? Ok... Mayb i go snatch josssticks... U know?\n',
#  'Pick me up at 6... Same place, car park there...\n',
#  "Oh... Tmr i've got drivin lesson... Cant make it...\n",
#  'Hiya, low batt :) your bus trip sounds kinda interesting... is it a single event or wat?\n',
#  'Hey remb to help me get the colourful map if possible... thx\n',
#  'Wif my fren. Finish discussing oredi mah. Then doing smth now.\n',
#  'Okay... Thanks.  i just boarded the bus\n',
#  'Hey in case i forget... All the best for your driving tmr... Try and relax. Dont bother abt the tester... And maybe you will get my tester!\n',
#  'I now watching tv, leaving home ard 8. Call u when i leave k.\n',
#  'Been busy wif work and trying to learn some computer programming by myself. Ü are tired out by yr hetic work?\n',
#  'What time? I need to practice for soccer\n',
#  "I'm going 2 orchard now already me reaching soon. U reaching?\n",
#  'Me 25 male...Chinese.Malaysian.\n',
#  'Reach Singapore about 2:30pm.   call you after arrived\n',
#  "I thk i wun b able to meet ü all at 5 to buy present... I'll meet ü all later... Call ü when i reach...\n",
#  "But if i go down rite it's not so early lor... Ard 8 like dat...\n",
#  'dun like tat leh MR joe.\n',
#  'Hi...Good morning...Care to intro...\n',
#  'The rest free nt? Den u wan to go chiong after dat?\n',
#  'No lah... But borburn coke is one o e more popular drinks lor... So is li en dancing?\n',
#  'ya lor. Gosh. I feel so embarrassed now... 2 hours without realising leh.... I hope nobody noticed... Damn paiseh.\n',
#  'Wa, today no nd work how come u wake up so early... Nope din meet jos, i went to meet family lor...\n',
#  'Got lah, but just came back only.\n',
#  'Girl, are you coming back to fetch me to airport\n',
#  'around 615 lor\n',
#  "My phone no batt. Pick me up at 2pm at drive one. Have you all eaten? Yun here using huixin's phone...\n",
#  'I will come at 8.40pm\n',
#  'Hello Yiyun..... How did your week go? Did ü had lots of fun in uni?   :)\n',
#  'CHEERS LOU! YEAH WAS A GOODNITE SHAME U NEVA CAME! C YA GAIL\n',
#  'At pub ah... U join me la den i go, gee... Lala workin there ah, okie, i shall ask her...\n',
#  'HAI!Nice 2 meet u! :- >im gal 18 chinese. U?hmm... <: > my hp num is 0165460953 more cheaper sms by phone!\n',
#  'Ya.Jos calld me juz nw mt thrus la.How r u?\n',
#  'If i jus wan trim a bit, go tony n guy, will they laugh or not, wait so long but only cut a bit. I duno if i wan dye\n',
#  'Yun ah...Driving nid 2 bring é advance theory bk nt?\n',
#  'y not i meet u at e mrt near ur sch? U goin there from ur sch rite? im on my way home from sch..\n',
#  "Dunno leh... Thk 5 lor...Haiz... Later i'll go take again... Cant stand it...\n",
#  'but then im like that one wat .. hard to change ...\n',
#  'Hey mel owes you money right? $5 remind me to pay you...\n',
#  'I still doing.. Intend to reach 10 plus.\n',
#  'Can ü join us for lunch on sun?\n',
#  'Tis few wks veri hot man. me in camp also terok. wöuld luv è weather there too\n',
#  'He eat his lunch oredi...\n',
#  'okay.Then c u at 10am at mpsh\n',
#  'somewhere out there beneath the pale moon light someone thinkin of u somewhere out there where dreams come true... nitenite & sweet dreams 2 u\n',
#  "Thanx 4 the time we've spent 2geva, its bin mint! Ur my Baby and all I want is u!\n",
#  'Hello h r u\n',
#  'Yah... But its really tough trying to learn it by myself wif books onli. But i wan a head start for next yr... So, whens yr overseas trip?\n',
#  'Haha... Use ur imagination la... Cya tmr...\n',
#  'Tq anyway w ur u? Need 2 know, w ur u from. Lanz.\n',
#  "Yay!I'm out!I'm in civilisation!Wat u doing now?\n",
#  'I reach already. Call me when u reach.\n',
#  "I'm gonna bug u.Irritate u.Can?Wat show u watchin?\n",
#  'Ok. Now walking to mrt, but going to rain soon.\n',
#  'In my mind nw no hv anythings beautiful! Jz hv shit!jz feel nt happy!\n',
#  'Ya la...No choice...Wat to do? U intro me someone beta lo...\n',
#  'Rem too feed million mum mum...\n',
#  'nyp marketin.jenniffer tpp.i tink i wun stay for long la-bth.so mafan.try out play enuf go home.haha-\n',
#  "Hmmm... I wont b able to make it... Unless ur goin 4 dinner... Kaiez, i'll msg em den tell u...\n",
#  'Hai,zepol!hmm..dum bored!haih.:-\n',
#  'Okie... So cya at our class outin lor... U goin rite...\n',
#  'whoo! Matthew rocks!\n',
#  'I forgot to ask ü if ü wan to color ur hair...\n',
#  "Hey dont save seat for rebecca... She's not going for lect.\n",
#  'Ha... Then play other things lar...\n',
#  'Hi guys, want 2 chat with a guy?\n',
#  'Tmr we meeting 2pm orchard mrt.... Ü enjoy yourself... Tmr then msg me... Dont anyhow drink hor\n',
#  'I thk dun wan lor... Cos ü need to stay there alone until quite late... So ü bot ur jeans oredi?\n',
#  'Yup. At e taka mango so many ppl. But i didnt bring e game.\n',
#  'Girl have you done your stats tut?\n',
#  'Hi niny how r ü.care to intro pls...\n',
#  'Okay. Then dont be late ah\n',
#  "Hi, i'm outside honors lab 5 now.\n",
#  'HKY, I remember I have to give u $30 (at Peace Centre 2 weeks ago). cc LCT\n',
#  "Ah... Guess i've got the nail on é head huh? Oh btw... I'm busy with é recruits cuz we just had an intake. Got to interview them. Shèésh. Tell me äbt é guy...\n",
#  'Hello people so is tomorrow afternoon meeting confirmed. Let me know pls. Was thinking we go esplanade for coffee at three pm. Is that ok... Elaine\n',
#  'Haha... Ok... Prob borburn coke?\n',
#  'joey Y no reply frm u can u msg me at 96537803\n',
#  'Huh? Can like that meh. Bishan already. Was eating. Haha.\n',
#  "Haha... I'm in bangkok now, holidayin... Wat abt u...\n",
#  '8332 2650 6006 all three buy 2 big 2 small, ok.\n',
#  'Oh.. I working till end of this mth.. But see if they want to extend me a nt.. Which company u working in? Dun u want to earn more money?\n',
#  'Ok i call n ask. I tot u check until too bored fall asleep liao... Hee...\n',
#  'Dunno they all i msg them they havent reply... If Ü going somewhere wif xinyi then neva mind...\n',
#  'I will be late. Sorry\n',
#  'Wat time u finish w ziping? Lets hv supper tonight n talk. U can?\n',
#  "Kaiez... U noe where's e place in bugis village?\n",
#  "Hmm... How early? I think i'll be there about 11... Eh... E stocks qn, i dun understand how he get e interest... Sigh...\n",
#  'Gd morning,how is lifè today?Gd?Taken ur breakfast?\n',
#  'oh cz1102? ya dat was me.i offline liao.im in clubrm ma\n',
#  "I'm out of da hse oredi... I dun dare ü go catch lar...\n",
#  "do u wanna come to my sch? :) but i gotta do proj after sch, for awhile only. i'll not fall sick at tis time la, im strong enough hehe.\n",
#  'Yup... I will be going with my hall.\n',
#  'I know since u calling her i dun msg her oredi. I new phone lar not used 2 it always type wrong thing.\n',
#  'Wat exactly happen... Y suddenly lk tt...\n',
#  'Or when u send u msg me. Thought  of going tomw early aft noon... Hee like a bit kiasu like t.\n',
#  "Did u use any probabilty for ur CLIPS? I'm really not sure how to make my rules more complex leh...\n",
#  "hi gal, can ask daddy 2 call me, i can't get thru his handphone, thks\n",
#  "Eh gal... U called me rite... What's up...\n",
#  'Da help desk pple email me n cc my sup say dat cgi not supported on e acct i applied 4... So i guess da sup surely thk i v stupid... So wat u doing?\n',
#  'FON hi female or male there?\n',
#  'Dunno how to play other things wat... Anyway, we not playin oredi...\n',
#  'Ok lar.. aiyo.. haha.. btw.. u but short hair already or not pretty girl..haha..\n',
#  'Ay abit later two?wad time is e show? Two got show?\n',
#  'Angel: hai gstring,me chi female.u leh\n',
#  'Help me feed e hamsters...\n',
#  'Hey think tmr i will take bus down. Dont be late ah.... Cya\n',
#  'I reach liao... Call me when ü all r here...\n',
#  "Can i meet u outside lt26? I'll b at e booth there at abt 130...\n",
#  "I'll prob end in july... Haiz... Anyway, i applied nus sci... nope, din apply smu, cos thk quite diff to get in oso...\n",
#  'Haiyoh i super tired. Wont go and see him lah\n',
#  'HEY HEY WERE THE MONKEES PEOPLE SAY WE MONKEY AROUND! HOWDY GORGEOUS, HOW U DOIN? FOUND URSELF A JOB YET SAUSAGE? LOVE JEN\n',
#  "Hey xin ah... I'll b a bit late... Cos rainin heavily...\n",
#  'Not yet... Reaching? So early? Thought you have driving... Starts at 2 right?\n',
#  'Kaiez... Wa u haven collect ah, thgt u collect oredi... Ok, call u later...\n',
#  "That's how pple learn rite ?\n",
#  'cos telemktin can get higher pay ones.heh2\n',
#  'Me very hungry... Ü come down faster lei...\n',
#  'Haven yet la... 330 den board wat...\n',
#  "opps.. im sorry..use too frequent le.. ok, tml thn tel me where to meet. ü how's ur headache now? fine oreadi?\n",
#  'I thot of only ask u n jun come...Den can eat dinner here u c. Wan? U discuss w her la...\n',
#  'Sen, u male o female\n',
#  'Haha but u got time 2 spare...\n',
#  "Hmmm... I'm free anyday except fri onwards... Ur decide which day wana come lor...\n",
#  "Do u have linear algebra past papers' sol??\n",
#  'Is it the last price?\n',
#  'have ü submitted? If not we can go tmr to the office of finance\n',
#  'Hey... You have driving lessons this weekend?\n',
#  'Block 221 Boon Lay Place\n',
#  'Po po ask u 2 go n take dumpling...\n',
#  'Hmmm... 230 lor... Where will ur b?\n',
#  'Fine. Gt posted to SAFTI as a medic\n',
#  "I'm walkin to e bus stop now...\n",
#  'Mimi40 icic. So wat u doing now? Working or studying?\n',
#  "Yeah...U hav a knack 4 sms-ing me when i'm just step 4rm knockin out.Funny thing is..I actually bother 2 reply..Which usually isn't e case.Nitey then go\n",
#  'Goto 2 malayu room lah! U can find sme cute gals!!!\n',
#  'bcz this is consider branded among the thumb drive mah, u get those no brand one, 64mb, abt 28 to 35\n',
#  'Tdy sit further back.\n',
#  'Its in ivle..Under exam papers..So i get ans frm u tmr..  Thanks..C u..\n',
#  'Hmmm, ok. Ü take care too... Good nite....\n',
#  "Hey i'm baking cookies now... You prepare the jar okay?\n",
#  'Hey, sorry i dun think can meet ü all today. Just realised got dance class at 4 ñ rushing a term paper. Sorry leh... Tml can?\n',
#  'I hang all my earrings one...\n',
#  'we just come out from turf club. both of is made $800 each.\n',
#  'Hello i am back... Just got back last night. Looking forward to seeing ya all. Will call u soon. Elaine.\n',
#  'I have got another similar laptop here, that could let u utilise and move the data that u need backing up to my documents folder before the back up. File size 142mb. Remember to bring the invoice , thanks.\n',
#  "Hey xin ah... I've got no lect tmr leh... But i may go to sch la, cos my sis is goin...\n",
#  'Hey! Send me the photo page !\n',
#  'Hey! U thai p.ple r suxs! No manners at all! So boring!\n',
#  'Joey: Yup,where u fr?\n',
#  'haha, dun worry, i started studyin few days ago.. sure can do! ;) i only smoke my tests and presentation, NOTHING else. dun think too much. Ü\n',
#  "Okie, good good...  den most prob i'll get it oso lor...\n",
#  'Thgt u lk to take fotos one...Really, mei mei la, nvr bluff u... Anyway only 1 pic, dont worry...\n',
#  'Haha... Ya its been quite hot e past few wk... Other than havin great food... Wat else did u do there? Muz been veri fun...\n',
#  'Dunno how come cannot go online leh, tt fuji...\n',
#  'Erm...I nv bring wallet...Mac muffin can nt?\n',
#  'Ok...\n',
#  'I can send mine 2 u, then u jus change lor but think u got 2 do it b4 office hour end.\n',
#  "Lolx...Dear girl...been a tiring day.Its not a matter of choice.But i'm gonna drop pretty soon. U on e fone again ah?\n",
#  'Haha... Ü mean mich din join her meh?\n',
#  "Dinner changed to tm becos xy can't make it on wednesday.\n",
#  'I thk u shd keep ur hair... U go survey all ur frens... Hee... I was thkg toni n guy... Cos my sis wan to dye hair...\n',
#  'gd mornin :) jus woke up ah? u got lesson today?\n',
#  'Haven sleep yet? How have you been recently? Hows orientation week?\n',
#  'U prefer other days or u wan mon n thu so u can come directly. Or u got free days? U choose lah, cos u e only one studying.\n',
#  'Hmm,if too late èn nvm lo. Nex2 Wk c how. n.n\n',
#  'She alone lah... Muz b w somebody meh...\n',
#  "Really... Okie... I'll go check...\n",
#  "Hmmm... I dunno if she will... But i dun thk she'll bring lor...\n",
#  'HI DARLIN IM MISSIN U HOPE YOU ARE HAVING A GOOD TIME. WHEN ARE U BACK AND WHAT TIME IF U CAN GIVE ME A CALL AT HOME. JESS\n',
#  'My grave is oriedi dug. Haha- well,jia you jia you! -short circuit le- haha-\n',
#  'Okay... I also dont feel like going leh.\n',
#  'On my way back to our place.\n',
#  "Hiya... How i rem it's blue or pink...\n",
#  'Okie found e place.. Hee hope i wun turn out to be a freak.. Hah..\n',
#  "I'll b sleepin after e awards show lor... Thk cant tok to ya tonite... Other day... Early nitez den...\n",
#  "I'm worried abt my hair leh\n",
#  'Hey... So qiao... U oso learn drivin here...\n',
#  'hi gal wat msg u send juz now?\n',
#  "okay. i'll jus wait for u there.\n",
#  'Huh... Thgt u registered oredi?I dunno wat will happen, try to find one lor in case...Kaiez, den cya at 1215...\n',
#  'I cannot go home late lah.Sigh.I want to watch that show too.\n',
#  'I had a gd time too... Thanx for da dinner...\n',
#  'Den how? When u wan lei? Happy birthday to u!\n',
#  'Or ü can go toa payoh central... Then ü can shop shop...\n',
#  'Lea sorry wat is digi?\n',
#  'Oh, they were juz commenting on its popularity. Hey, your dog looks real cute.\n',
#  'Get my comp configured lor... Din noe have to wait so long one...\n',
#  'fion wana meet up.btw,ü got drivin basic -book?\n',
#  'Yup... Everything... You can ask the instructor stuff\n',
#  'good night and sweet dreams ttfn!\n',
#  "Oh ok... But wa's coming from east west line so i think easier for her cos she dunno how to get to nel line... Haha...\n",
#  'Ok, im done liao... Where r ü ?\n',
#  'Hmmm, ok. I got off on the 8th of next month. Hope you will be free for a lunch then...\n',
#  'fast one tday....my fren gotta work tml\n',
#  'Race 6 -8 Realistic never win for 1 whole yrs. but ask saimee to try outsider chance. ever won wet 3 time 1200 n 1400. Out do not bet big jame seed.\n',
#  "Login thru da school comp lor... I thk it's smth like h drive... Muz in sch then can access... U noe wat's VPN? Need to dload anything to use it?\n",
#  'Helo k.reen n p.ple.hw r u?care 2 chat any1?\n',
#  'Halo cy càrè for ä intro\n',
#  "Hey... I just booked e place for 630pm... Couldn't get an earlier time... So you all wanna meet later? Cos tanjong pagar got ntg to do while waiting...\n",
#  "Joan nvr reply me lei.call her oso never ans.i tink she workin now.k,so i reach parkway le i call u la.cya.i'll try contactin her again...\n",
#  'U still wana watch bruce almighty?\n',
#  "It's ok.. Happy studying..\n",
#  'Yup. E sch website got u search within e sch pages.\n',
# ...
#  "Haha... I'm going to buy sandals... How to go queensway ah? Any cute hunks around? Wah. So late ah\n",
#  'Yupz... Sure... Evenin rite...\n',
#  'Yah, haven chat wif ü for long time. Wanna know how ü been recently... Maybe can jio ü out after my course ends. Juz came back this afternoon from field camp.\n',
#  'Celine or u trying msg to me? My hp is +6590957823\n',
#  'No,cos i din get an a for gp last yr.If yr work is making ü tired,ü shld quit asap. Find a less taxing job. Ü will have more time to go out too...  :)\n',
#  'Lunch\n',
#  "Ya hor... U dun mind can liao, i'm ok w it...\n",
#  'But cun lah... go next wk? Act where ü wanna go?\n',
#  'Ok, then I will try to get back to u before 1200 tommorow.thank you and gud nite =)\n',
#  'y study til so late? becos i took up ur daytime? i wan to do abit of my another proj first before i slp.. So not slpin yet..\n',
#  'Ok lor... I buy dinner for them now oredi...\n',
#  'Im not workg...Wat time junmèi aft work? I saw david ytd...\n',
#  'Eh where michelle studying now ah?\n',
#  'Ok since everyone can make it on mon. Lets make it at seven thirty Taka fountain. Is indonesian food at Sanur ok or Suntec.\n',
#  'Ü havent receive yet meh? I just got it today... brown envelop a lot of things\n',
#  "Hey i'm at the science canteen... near chi cooked food come find me!\n",
#  'So long never hear from you le . . . How have you been.\n',
#  'ard 7 .. go near ur hse there ?\n',
#  'Yup... Taken oredi... Thanx...\n',
#  "I'm comin back 4 dinner leh...\n",
#  'Hey. The inaug ceremony at university cultural center...\n',
#  'Whoa..With friends or fam?\n',
#  'Then how ü wan to go early a not... Ask her to wait at bishan then ben can fetch her but she wun wake up so early...\n',
#  "Can i ans ù later i'm gossiping wif my fren. Oh fyi, i'm still in camp. U wun b sleepin early rite?\n",
#  'Huh cum my hse 4 wat v messy lei...\n',
#  'Xian but go out also nothing 2 do.\n',
#  'No need. ic. Go there fill form can liao\n',
#  "Corinna say can... So i'll frame it lar\n",
#  'I in hall... yes?ms me ah?\n',
#  'hi tazz, only both of us, intro pls.\n',
#  'You study wat course?\n',
#  "My frens eatin den i'm drinkin lor...\n",
#  'Hmmm.... No la... Thk we will go n apply 4 some stuff first....\n',
#  'Die got traffic jam will reach in ard 8 min... Ü go buy newspaper...\n',
#  "Nope... I'm reaching home. Take my bag then go sch.\n",
#  'I dun mind... Kaiez, set liao...haiz, u muz b slackin now, so gd...\n',
#  "Don't ask...Its for a stupid reason.Anyway,i'll just focus on being around in mainland.U can come out?\n",
#  "Hey gelek! Hee enjoy ur trip tmr k! Rem ah.. Dun eat too much ah! If not u'll gain 3.5 kg! Haha no lah jus enjoy urself!\n",
#  'everything. i think ard 180 to 200. the detail discuss wif the aprent. so he interested?\n',
#  'Izit... Den i muz go look ard liao...U interested to change jobs too... Haha, den can go look ard together...\n',
#  'Hey my email is whackers33@hotmail.com. Haha, know this reply is darn late, forgot all abt it till now. Oh anyway ü wanna catch a show this afternoon say 3 plus\n',
#  'okie tink meet up again then,paiseh leh.\n',
#  'I in LT 24..Get frm u tut 8 later..\n',
#  'Anyone has a cultural or ethnic top i can borrow?\n',
#  'What are u doing tonight.Go Geylang eat.\n',
#  "No wat, where got ugly... Aiyo, smebody so vain ah...Only saw one pic tt's u alone, e rest is gp foto liao...\n",
#  'Hmmm... On mon can... Cos my other fren oso comin to my hse on mon... Gee...\n',
#  'U pay oredi... Den mine must b 35 lor... Mine still do a lot of thgs, haha...\n',
#  'Yun! You coming to find me later? I havent ballot for my eng mod yet... Haiyoh.\n',
#  'Did u have a gd rest my dear?\n',
#  'hello s56! its being sometime huh... Tonite free? Club @S.O.S.... REPLY!\n',
#  'I found it liao lar... Ü finish ur lesson liao ar...\n',
#  'im watchin smallville.. dozin off.. dun think im goin to study tonite.. u studyin now ah?\n',
#  'You got do the economics aspect of fusion?\n',
#  "Hmmm... I'm out w my fren today... Y?\n",
#  'Hey are you all free to meet on sunday afternoon or mon night...am leaving next week. Elaine\n',
#  'Crown so late still got open... Y dun buy liao lei...\n',
#  "Yupz... I'm goin... Shld b able to rent la, if they r available there...\n",
#  'U all confirm at good wood park...\n',
#  'Hey... How r u? Din contact u 4 quite some time...\n',
#  'Yar lor in soc face muz be v thick one...\n',
#  "Okie okie.. I'll update u bout e situation another day then.. Hee\n",
#  'No nd me to intro someone oso got lotsa admirer liao wat... K la, thurs no changes liao ah...\n',
#  'Konichiwa, how r u? wat r u doing?\n',
#  'Hey come online? We discuss eng with regina\n',
#  "Happy Valentine's Day... May this day of yours be blessed with happiness n laughter... Good day ahead.\n",
#  'U go chop seats in e canteen b4 2 ok... Den i come out can eat oredi...\n',
#  "Kid's shop selling clothes izit...\n",
#  'Anybody wants to go shopping tmr ?\n',
#  'We din do much, cept i treated them to a movie.Me meeting menghong for dinner n then we r going to see a squash fren of ours at causeway pt.Had yr dinner yet?\n',
#  'Juz now his qn i reply liao...  So ü asking him? If ask oredi then tell me...\n',
#  "I walked an hour 2 c u! doesn't that show I care y wont u believe im serious?\n",
#  'Den tmr ur fetchin me 4 lunch huh?\n',
#  'Dan 4gt it.u dun wan 2 intro n i jus follow suit.\n',
#  'Of cos e one in my toilet la... Tt one den correct wat..\n',
#  'Haha... True la, spore got nothin to do one....thk u will end up watchin movie...\n',
#  'Orhz ü mean the linear algebra is it? Haha... Thought ü talking abt cz... My lesson jus end... Where ü?\n',
#  'Its ok. Hi ranger u m or f? Workg? Age? Its ok iregardles wht u r, ok. We r frens, right? Tell me more, ok.\n',
#  '1-15pm ,reached about 5pm\n',
#  'yupz...if u cant den i help u collect lor...\n',
#  'Hey.... Tmr you wanna meet at 10am or meet after lunch then we dont go for the free abt in the morning?\n',
#  'K.wad time?meet at ecp ah?or parkway or wads?btw,who else goin?\n',
#  'Si.como no?!listened2the plaid album-quite gd&the new air1 which is hilarious-also bought"braindance"a comp.ofstuff on aphex\'s ;abel,u hav2hear it!c u sn\n',
#  'Vet! Wad offer?!  engineerin wil need maths ñ phy. Revise english lo-cos sure got tis subject.haha-\n',
#  'Thank u. IT BETTER WORK OUT CAUSE I WILL FEEL USED OTHERWISE\n',
#  'Hey got space for one more seat?\n',
#  'Hi! guys n grls somebdy wan 2 chat with me..\n',
#  'Be at home to stay with mother more please.\n',
#  'Wot is u up 2 then bitch?\n',
#  "No la... I'll only take those tt nd me 4 one or 2 days lor... C first, mayb i'll go b a waitress...\n",
#  "just for drinks only..no dance..how abt it?we'll leave by1?\n",
#  'Harlow. Hws ur wk end?\n',
#  'simon, cut the idols some slack - they are juz kids with a dream!\n',
#  'Haha cant help much.\n',
#  'They login thru wat?\n',
#  'Hmmm... Can only make it from evenin onwards....\n',
#  'Eh not meetg le...Other days den meet k. Jun goin home le...\n',
#  'Yup can see millian! No need sq table lor. What time?\n',
#  'Can you come online?\n',
#  "Oh... I juz checked n realize my lesson is at 440...Haha, tt means i'll cya den...\n",
#  "hey,how have ya been lately? Great i hope! I've been busy working out,working ñ studying my ass off!-smiles-\n",
#  'Ic... I tot u go wif xf... Hee... Joking lar...\n',
#  'Hmm.....seems lk ur playin hard 2 gt type....hehe..:p\n',
#  "Nope i'm watching tv at home. How come u bored dun u haf things 2 do in office?\n",
#  'fun..How i wish i can spend this coming v day with u..Hee..Can?Future guy\n',
#  'Wa... I ate one cup of yoghurt, yum yum...\n',
#  'Ya...Dat dae i check dun haf...So how? Where u wan?\n',
#  'haha. i sympathise! i got to go to school on saturday for only one 1 hour lecture!\n',
#  'Hey free tonight for online chatting session at 11pm\n',
#  'Ok gd, thats wat every one who replied is saying. Let u noe results later ü\n',
#  'No lah,dont be 2sensitive on sars,actually i find u cute so decide 2made frd with u.\n',
#  'Opps... sorry.. i kept tinking tmr is wed.. sorry.. haha..\n',
#  "It's at maxwell road? V far walk a not ?\n",
#  'W don get the wrong idea ok .. Im curious only ..\n',
#  'malayu all kayu leh.\n',
#  'CDD wants those on MC to be reported immediately becoz of SARS.Action will be taken against non compliance\n',
#  'I be goin from hm. Wat time n where to meet?\n',
#  "So is our dear pink here oredi? Saved a seat 4 u... I'm at e left side...\n",
#  "Really... Haha, i'm at yck, near amk... So gd get half day off...\n",
#  'tmr i got driving... 1245 slot.... Meet ü after that ? The puzzle is almost complete... Left the eyes and ears and nose\n',
#  'wah, so expensive ah! thermometer spoiled issit..ü did ur sis feel unwell? i reached home le, goin to bathe. Ü\n',
#  'We juz finish buyin our grocery... Goin to cook dinner tonite la...\n',
#  "Eh. I'm still at the bus stop... Missed the bus. So i might be later than you\n",
#  "Dun worry la.yun so clever sure can make it one. n.n i'm waitin to sit ür car. Hee-\n",
#  "Can't u juz give me ur intro 1st plzZz...\n",
#  'ger, wan tuition? p 3, live in serangoon.\n',
#  'This time not pain leh.. Haha. Okay. Cya on wed!\n',
#  "ger ah,dun forget tt we'r meetin today k.when i end i msg ü k.\n",
#  "Sux big time... Feel so lazy but there's so much to go... U noe sth, i discovered mr ng's homepage by chance... He's actually 30... So young...\n",
#  "Eh... U found job yet? I've got one... Have u done any accountin b4?\n",
#  'Arghh... I fail my evaluation again... Got 6 mistakes tis time...\n',
#  "Huh... Dun get u... Wat's up... I'm w my bf now... Y muz get somewhere quiet... U r weird today...\n",
#  'James: Hi everybody\n',
#  "I was drinkin at spinelli's at heeren ma... Ur shift manager leh, u forgot liao ah...\n",
#  "Me admin oso... I'm quitin nxt wk, haha, wana take a break liao...\n",
#  'If dun hav bus not worth it lo.try tp one.ask if they sellin hse.or mon èn look lo.dun worry sure can find one.ür car learnin no,wkends meh?\n',
#  'eh.. later meet ya all at tp mrtk..445pm\n',
#  'I know dat feelin had it with Pete! Wuld get with em , nuther place nuther time mayb?\n',
#  'Wha buying new car?\n',
#  "I'm still at comp centre leh... There's still a long queue... Sianz... I might not b able to meet ur...\n",
#  'Daddy going out tonight... Ü come home urself... Buy rice oredi...\n',
#  'Hi..any gal like 2 chat\n',
#  'Ya... Wont forget u... Now have to help xin chop one more seat, i became e choppin gal oredi...\n',
#  'Hey xin ah...R we goin 4 lesson on thurs? Oh fri rite, we r attendin e theory lesson hor...\n',
#  'Ay i exam period ah...seow ah. Dyin--\n',
#  'Yest nite... I was watchin e news ma... They were tokin abt farrer park, den ur were havin a game ma, so got filmed oso...\n',
#  "Hmmm... As usual, did lotsa shoppin, den went 4 tours lor... It's more fun goin w frens lor...\n",
#  'then it can moisturise our skin. and rub in circular motion. u wash face, tone,then put a bit of jelly and cream onto ur hand,and tap it on your face,\n',
#  "Hey its meijun's bday today so we share n treat her to crepes k.\n",
#  'Bad news... I forgot put my cash card when entering erp...\n',
#  'no, gotta go sch tml. only all lectures are cancelled, stil got tut and lab.. actually not all fren tat i gossip wf, actually only 2 close frens,both vry 38.Ü\n',
#  "I'm goin to com centre now. Will b back to sci later... When u free..\n",
#  'Hi.Is $45 ok?if possible i would like to get the book today ard 1700 - 1730 pm.\n',
#  'then, maybe u can ask her 2 read more review b4 buying lor\n',
#  'Tiffany here,frm gek1005 project grp.. R u guyz free on thur b4 12 or aft 2pm?\n',
#  'Oh my new job hvn start,so resting nw.Iras job end on tues.I going find jos nw.\n',
#  "Hello....everybody! Nice to meet ü all, anyway my name is 'calrie' hope ü guys sms or cal me. My num is 93517902 :)\n",
#  "My house there...Jog outside pple's houses.Ü got bring ür dog along?\n",
#  'Okay... Did you bring water?\n',
#  'Feel like going... But not prepared la...\n',
#  'Hello darlin ive finished college now so txt me when u finish if u can love Kate\n',
#  'Haiyoh... It was so crowded... We didnt buy anything... Haha... Lots of pple in town. So mon we go facial with ü then go shopping?\n',
#  "I'm at wisma u reach call me\n",
#  'So cheap thanx... U board da plane oredi?\n',
#  'Hey xin ah... U goin 4 e rag day tmr?\n',
#  "Guess u'll b usin ur new line... Anyway, i chose nus sci... U choose nus or smu 4 ur biz ad...\n",
#  'Gee...missed ür bdae...happy belated bdae!!juz checked my calender den realized it was on wed...Paiseh hor...too busy la...hope itz nt too late...hee...-.-"\'\n',
#  'Hi! How was your weekend? Did you have a good time?  :)\n',
#  'Not heavy metal can liao, no preference la.. Where u goin tmr? Ur frens all guys ah...\n',
#  'I thk chinese tester better...\n',
#  'Hmmm... I thk can...\n',
#  'Does that mean you wont be appearing?\n',
#  'Really only today? Topshop n miss self ridge oso got store wide discount...\n',
#  "No need... I'll get my dad to pick me up...\n",
#  'Okay... So where shall i meet ü all?\n',
#  'Haha no la do sci gd mah where é most jobs are haha so wil c ü ard in nus!\n',
#  'Eh i tink i nt going 4 bash...But my frens going chiong...Wanna go? Eh r u all free dat dae? I was tinking of dinner...\n',
#  'Hey... We comin home liao...\n',
#  'Haha. Sure anot? Oni a bit. Haha. Tats bc u go thailand mahz. Mine not more thn 15.\n',
#  'Poor me still using 8310. Haha... nsf are the poorest boys around. So are yr exams over yet?\n',
#  'Angel sms me at 0164330931 ok? Chinese male here\n',
#  'He told me 11am when i say that i want it as early as possible... Oh well...\n',
#  'both.. but no replies as yet..\n',
#  'Yup... Okay... Nothing nice to go for on thurs except pilates leh\n',
#  "Soc...Sch of computing...Noe any frens who's there too? Coz i dunno anyone...Haha heard u got into sci\n",
#  'Are you doing anything tomorrow?\n',
#  'Wha ur sis cooking. Hmm ok lor. At first thought like need 2 tell e recept, then need 2 change. Then reach already call each other lor.\n',
#  'See ü mike Elaine remember to sms at my num.i got to go.see ü all...\n',
#  'Get smth lo...Den nvm ba...Heh.\n',
#  "Oh ok. Too tired today? Hee... I'm just leaving my house now. Gonna be late again... Ahhhh...... Hey when ü wanna meet up with weiyi?\n",
#  'Yupz... Not bad lor... Weather is good... Haha, nice to shop lor...\n',
#  'No got new job at bar in airport on satsgettin 4.47per hour but means no lie in! keep in touch\n',
#  'Hey our jazz dance teacher is really the dancer for tcs... You watching the sun yan zi thing?\n',
#  'How u look like\n',
#  'Torquay is along great ocean rd... Where r ü now?\n',
#  'Find one day can take photo with your dog...Ok...\n',
#  "Aiya... I wont mind one lor... Not so petty... Juz finish my assessment... Haiz, guess it's quite lousy...\n",
#  'Den u park in sch la... If not den u bring it to lect lor...\n',
#  'Ok , I will follow your instruction.\n',
#  'No lah. C u tom then ü\n',
#  'Ok we meet after yr trip k. Have fun n happy birthday in advance.\n',
#  'Ard 20 smth or 30 lk dat lor... I wan like those surf shorts one lor... Ü finish dinner? Wat did ü haf? We going 4 dinner now...\n',
#  'Yun ah,ü back?\n',
#  'Haha... Mayb later i go n find ü.Ü jogging today?\n',
#  'Wad u want to major?\n',
#  'any tit bits over there?\n',
#  'Eh wanna come out for dinner? Me and deckie in suntec\n',
#  'Oh, hope ü have a good trip. Dun worry, i ll try hard not to miss you. Haha....  :-p\n',
#  'Can dont reply him first, then wait till he ask u again then u ask him how many ppl going. Depend on ur relationship w him lor. If really v odd then dont go .\n',
#  'Hey where r ü im here liao\n',
#  'Aiyo, i thought t webpage say can. Then now how? T acct support wat language? Me doing nothing much c tv lor. U?\n',
#  'Hi babe its me thanks for coming even though it didnt go that well!i just wanted my bed! Hope to see you soon love and kisses\n',
#  'k. Mayb i will pop by in lib coz gotta return books\n',
#  'Bedok town i stayback\n',
#  "jolene says:there'll b a bbq on 17/5 at julia's hse.i've yet to confirm the time.can u make it?hee do reply me asap k?help spread the news too.thanx!tk care\n",
#  ...]

# %%
df = pd.DataFrame()
df["input"] = inp2
df["output"] = tgt2
df["y"] = list("2"*len(inp2))

# %%
df
# Out:
#                                                   input  \
# 0                     U wan me to "chop" seat 4 u nt?\n
# 1     Yup. U reaching. We order some durian pastry a...
# 2     They become more ex oredi... Mine is like 25.....
# 3                             I'm thai. what do u do?\n
# 4     Hi! How did your week go? Haven heard from you...
# ...                                                 ...
# 1995  Hmmm... Thk i usually book on wkends... Depend...
# 1996  ask them got any sms messages to gif me lei......
# 1997                          We r near coca oredi...\n
# 1998  hall Eleven. Got lectures le mah.èn forget abt...
# 1999  I Bring for u. I can not promise u 100% to win...
#
#                                                  output  y
# 0      Do you want me to reserve seat for you or not?\n  2
# 1     Yeap. You reaching? We ordered some Durian pas...  2
# 2     They become more expensive already. Mine is li...  2
# 3                           I'm Thai. What do you do?\n  2
# 4     Hi! How did your week go? Haven't heard from y...  2
# ...                                                 ... ..
# 1995  Hmm. I think I usually book on weekends. It de...  2
# 1996  Can you ask them whether they have for any sms...  2
# 1997                        We are near Coca already.\n  2
# 1998  Hall eleven. Got lectures. And forget about co...  2
# 1999  I bring for you. I can not promise you 100% to...  2
#
# [2000 rows x 3 columns]

# %%
'''THIS FUNCTION REMOVES THE SPACES BETWEEN THE CONTRACTED WORDS AND REMOVING UNNECESSARY SPACES IN THE SENTENCES
            ca n't ==> can't 
            I 'm ===> I'm ...etc
'''
def remove_spaces(text):
    text = re.sub(r" '(\w)",r"'\1",text)
    text = re.sub(r" \,",",",text)
    text = re.sub(r" \.+",".",text)
    text = re.sub(r" \!+","!",text)
    text = re.sub(r" \?+","?",text)
    text = re.sub(" n't","n't",text)
    text = re.sub("[\(\)\;\_\^\`\/]","",text)
    
    return text


'''THIS FUNCTION DECONTRACTS THE CONTRACTED WORDS'''
#REF : https://stackoverflow.com/questions/19790188/expanding-english-language-contractions-in-python

def decontract(text):
    text = re.sub(r"won\'t", "will not", text)
    text = re.sub(r"can\'t", "can not", text)
    text = re.sub(r"n\'t", " not", text)
    text = re.sub(r"\'re", " are", text)
    text = re.sub(r"\'s", " is", text)
    text = re.sub(r"\'d", " would", text)
    text = re.sub(r"\'ll", " will", text)
    text = re.sub(r"\'t", " not", text)
    text = re.sub(r"\'ve", " have", text)
    text = re.sub(r"\'m", " am", text)
    return text


'''THIS FUNCTION PREPROCESSES THE TEXT '''
def preprocess(text):
    text = re.sub("\n","",text)
    text = remove_spaces(text)   # REMOVING UNWANTED SPACES
    text = re.sub(r"\.+",".",text)
    text = re.sub(r"\!+","!",text)
    text = decontract(text)    # DECONTRACTION
    text = re.sub("[^A-Za-z0-9 ]+","",text)
    text = text.lower()
    return text

# %%
df["processed_input"] = df.input.apply(preprocess)
df["processed_output"] = df.output.apply(preprocess)

# %%
df.head(5)
# Out:
#                                                input  \
# 0                  U wan me to "chop" seat 4 u nt?\n
# 1  Yup. U reaching. We order some durian pastry a...
# 2  They become more ex oredi... Mine is like 25.....
# 3                          I'm thai. what do u do?\n
# 4  Hi! How did your week go? Haven heard from you...
#
#                                               output  y  \
# 0   Do you want me to reserve seat for you or not?\n  2
# 1  Yeap. You reaching? We ordered some Durian pas...  2
# 2  They become more expensive already. Mine is li...  2
# 3                        I'm Thai. What do you do?\n  2
# 4  Hi! How did your week go? Haven't heard from y...  2
#
#                                      processed_input  \
# 0                       u wan me to chop seat 4 u nt
# 1  yup u reaching we order some durian pastry alr...
# 2  they become more ex oredi mine is like 25 so h...
# 3                             i am thai what do u do
# 4  hi how did your week go haven heard from you f...
#
#                                     processed_output
# 0      do you want me to reserve seat for you or not
# 1  yeap you reaching we ordered some durian pastr...
# 2  they become more expensive already mine is lik...
# 3                           i am thai what do you do
# 4  hi how did your week go have not heard from yo...

# %%
df.drop(["input","output"], axis = 1, inplace = True)

# %%
df.head(5)
# Out:
#    y                                    processed_input  \
# 0  2                       u wan me to chop seat 4 u nt
# 1  2  yup u reaching we order some durian pastry alr...
# 2  2  they become more ex oredi mine is like 25 so h...
# 3  2                             i am thai what do u do
# 4  2  hi how did your week go haven heard from you f...
#
#                                     processed_output
# 0      do you want me to reserve seat for you or not
# 1  yeap you reaching we ordered some durian pastr...
# 2  they become more expensive already mine is lik...
# 3                           i am thai what do you do
# 4  hi how did your week go have not heard from yo...

# %%
df.shape
# Out:
# (2000, 3)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 3 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   y                 2000 non-null   object
#  1   processed_input   2000 non-null   object
#  2   processed_output  2000 non-null   object
# dtypes: object(3)
# memory usage: 47.0+ KB
